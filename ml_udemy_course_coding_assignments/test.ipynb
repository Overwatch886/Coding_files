# %%
import pandas as pd 
data = [
    {'Name': 'Israel', 'Age': 16, 'Course':'Computer Science'},
    {'Name': 'Dayo', 'Age': 19, 'Course':'Animal Science'},
    {'Name': 'Bisola', 'Age': 14, 'Course':'Chemistry'}
]
df = pd.DataFrame(data)
print(df)
# Out:
#      Name  Age            Course
# 0  Israel   16  Computer Science
# 1    Dayo   19    Animal Science
# 2  Bisola   14         Chemistry

# %%
df.Name
# Out:
# 0    Israel
# 1    Bisola
# Name: Name, dtype: object

# %%
df.loc[0,'Age']
# Out:
# np.int64(16)

# %%
df.at[0,'Age']
# Out:
# np.int64(16)

# %%
df.iat[0,1]
# Out:
# np.int64(16)

# %%
df.iloc[0,0:2]
# Out:
# pandas.core.frame.DataFrame

# %%
df
df.drop(1,axis=0, inplace=True)

# %%
df
# Out:
#      Name  Age            Course
# 0  Israel   16  Computer Science
# 2  Bisola   14         Chemistry

# %%
df =df.reset_index()

# %%
df
# Out:
#    index    Name  Age            Course
# 0      0  Israel   16  Computer Science
# 1      2  Bisola   14         Chemistry
