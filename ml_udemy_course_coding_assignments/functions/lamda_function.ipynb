# %% [markdown]
# ### Lamda Functions

# %% [markdown]
# #### Lambda functions have any number of argunments but only one expression

# %% [markdown]
# When applying inbuilt functions with the help of map, you don't have to use brackets
