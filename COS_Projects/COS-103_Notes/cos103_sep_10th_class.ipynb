# %%
name = "Israel"
age = 16
print("My name  is {} and I am {} years old.format(name, age)")
print(name[1])
print(name[3])
print(name[1])
# Out:
# My name  is {} and I am {} years old.format(name, age)
# s
# a
# s

# %% [markdown]
# ### Escape Sequence
# Using something to represent special characters in strings e.g \n(new line), \t(tab)
#
# To escape a character which would normally be part of the code, use \ to escape

# %%
print("Hello \"World\"")
print("He said \"He is in the school\"")
# Out:
# Hello "World"
# He said "He is in the school"
